# %%
import torch
import numpy

# %%
import imageio
dir_path = "../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 94/99  (94.999/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol.shape
# Out:
# torch.Size([99, 512, 512])

# %%
vol = torch.transpose(vol,0,2)
vol.shape
# Out:
# torch.Size([512, 512, 99])

# %%
vol = torch.unsqueeze(vol, 0)
vol.shape
# Out:
# torch.Size([1, 512, 512, 99])

# %%
vol
# Out:
# tensor([[[[ -985.,  -982., -1022.,  ...,  -979.,  -977., -1003.],
#           [-1016., -1015., -1022.,  ..., -1024.,  -980.,  -938.],
#           [-1024., -1020.,  -991.,  ..., -1021., -1010.,  -980.],
#           ...,
#           [ -920.,  -880.,  -858.,  ...,  -780.,  -836.,  -859.],
#           [ -871.,  -907.,  -948.,  ...,  -837.,  -912.,  -886.],
#           [ -876.,  -885.,  -921.,  ...,  -991.,  -998.,  -915.]],
#
#          [[ -990.,  -989., -1011.,  ...,  -906.,  -999., -1017.],
#           [ -984.,  -969., -1005.,  ...,  -943.,  -995., -1013.],
#           [-1008.,  -978.,  -965.,  ..., -1024., -1024.,  -995.],
#           ...,
#           [ -942.,  -854.,  -899.,  ...,  -824.,  -909.,  -928.],
#           [ -879.,  -868.,  -914.,  ..., -1002., -1001.,  -965.],
#           [ -855.,  -850.,  -874.,  ...,  -978.,  -834.,  -865.]],
#
#          [[ -999., -1020.,  -983.,  ..., -1016.,  -975., -1023.],
#           [ -963.,  -980., -1012.,  ...,  -863.,  -916., -1009.],
#           [ -996.,  -972.,  -993.,  ...,  -988.,  -958.,  -982.],
#           ...,
#           [ -944.,  -924.,  -950.,  ...,  -931.,  -926.,  -867.],
#           [ -905.,  -928.,  -918.,  ...,  -977.,  -872.,  -849.],
#           [ -873.,  -899.,  -914.,  ...,  -867.,  -782.,  -809.]],
#
#          ...,
#
#          [[-1017.,  -988., -1013.,  ..., -1010., -1024., -1010.],
#           [-1000.,  -981.,  -948.,  ...,  -956.,  -996.,  -988.],
#           [ -979.,  -988.,  -964.,  ...,  -971.,  -990., -1005.],
#           ...,
#           [ -893.,  -909.,  -939.,  ...,  -874.,  -909.,  -968.],
#           [ -895.,  -909.,  -968.,  ...,  -880.,  -947.,  -943.],
#           [ -933.,  -977.,  -898.,  ...,  -921.,  -964.,  -963.]],
#
#          [[-1008.,  -977.,  -980.,  ...,  -896.,  -987.,  -984.],
#           [-1009.,  -974.,  -966.,  ...,  -953.,  -915.,  -999.],
#           [-1021.,  -993., -1011.,  ..., -1008.,  -979.,  -938.],
#           ...,
#           [ -917.,  -829.,  -868.,  ...,  -887.,  -794.,  -896.],
#           [ -869.,  -901.,  -978.,  ...,  -930.,  -866.,  -895.],
#           [ -982.,  -964.,  -910.,  ...,  -903.,  -852.,  -928.]],
#
#          [[ -971.,  -980.,  -967.,  ...,  -928.,  -847.,  -968.],
#           [ -999., -1016., -1008.,  ..., -1022.,  -967.,  -958.],
#           [ -987., -1015.,  -996.,  ...,  -962., -1002.,  -916.],
#           ...,
#           [ -955.,  -829.,  -827.,  ...,  -890.,  -917.,  -861.],
#           [ -867.,  -894.,  -946.,  ...,  -886.,  -881.,  -864.],
#           [ -936.,  -991.,  -934.,  ...,  -913.,  -922.,  -856.]]]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[10])
